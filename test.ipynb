# %%
import pandas as pd

# %%
df = pd.read_csv("JobListing.csv")

# %%
df
# Out:
#                              JobTitles                        Jobsubtitles  \
# 0              Senior Python Developer             Senior Python Developer
# 1                      Energy engineer                     Energy engineer
# 2                      Legal executive                     Legal executive
# 3               Fitness centre manager              Fitness centre manager
# 4                      Product manager                     Product manager
# ..                                 ...                                 ...
# 95  Museum/gallery exhibitions officer  Museum/gallery exhibitions officer
# 96            Radiographer, diagnostic            Radiographer, diagnostic
# 97              Database administrator              Database administrator
# 98                  Furniture designer                  Furniture designer
# 99                         Ship broker                         Ship broker
#
#                                JobLocation         Jobdate
# ...
